# %%
# create super groups for profession kinds

# %%
profs = ProfessionType.objects.all()
len(profs)

# %%
landwirtschaft = []
landwirtschaft_p, _ = ProfessionType.objects.get_or_create(name='Landwirtschaft')
bedienstete = []
bedienstete_p, _ = ProfessionType.objects.get_or_create(name='Bedienstete')
handel = []
handel_p, _ = ProfessionType.objects.get_or_create(name='Handel')
geistige = []
geistige_p, _ = ProfessionType.objects.get_or_create(name='Geistige')
wirt = []
wirt_p, _ = ProfessionType.objects.get_or_create(name='Wirte')
handerk = []
handwerk_p, _ = ProfessionType.objects.get_or_create(name='Handwerk')
naherin = []
naherin_p, _ = ProfessionType.objects.get_or_create(name='Näherin')
tagwerker = []
tagwerker_p, _ = ProfessionType.objects.get_or_create(name='Tagwerker')

mediziner = []
mediziner_p, _ = ProfessionType.objects.get_or_create(name='Mediziner')

student = []
student_p, _ = ProfessionType.objects.get_or_create(name='Student')

paechter = []
paechter_p, _ = ProfessionType.objects.get_or_create(name='Pächter')

nutznie = []
nutznie_p, _ = ProfessionType.objects.get_or_create(name='Nutznießer')

mesner = []
mesner_p, _ = ProfessionType.objects.get_or_create(name='Mesner')

inhaber = []
inhaber_p, _ = ProfessionType.objects.get_or_create(name='Inhaber')

ingehaus = []
ingehaus_p, _ = ProfessionType.objects.get_or_create(name='Ingehäuser')

inwohner = []
inwohner_p, _ = ProfessionType.objects.get_or_create(name='Inwohner')

sonstiges = []
sonstiges_p, _ = ProfessionType.objects.get_or_create(name='sonstiges')

for x in profs:
    if "Bauer" in x.name:
        landwirtschaft.append(x)
        x.parent_class = landwirtschaft_p
    elif "Bäuer" in x.name:
        landwirtschaft.append(x)
        x.parent_class = landwirtschaft_p

    elif "Wirt" in x.name:
        wirt.append(x)
        x.parent_class = wirt_p

    elif "Tag" in x.name:
        tagwerker.append(x)
        x.parent_class = tagwerker_p

    elif "Näh" in x.name:
        naherin.append(x)
        x.parent_class = naherin_p

    elif "Dinst" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p
    elif "dienst" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p
    elif "Knecht" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p
    elif "knecht" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p
    elif "Magd" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p
    elif "magd" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p
    elif "zofe" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p
    elif "Köchi" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p
    elif "Häuserin" in x.name:
        bedienstete.append(x)
        x.parent_class = bedienstete_p

    elif "aplan" in x.name:
        geistige.append(x)
        x.parent_class = geistige_p
    elif "iester" in x.name:
        geistige.append(x)
        x.parent_class = geistige_p
    elif "ooperat" in x.name:
        geistige.append(x)
        x.parent_class = geistige_p

    elif "meister" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "Zimmermann" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "Weber" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "Maurer" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "Bäcker" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "üller" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "Rader" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "Fleischhacker" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "Wollschläger" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "macher" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p
    elif "gesell" in x.name:
        handerk.append(x)
        x.parent_class = handwerk_p

    elif "andels" in x.name:
        handel.append(x)
        x.parent_class = handel_p
    elif "Händl" in x.name:
        handel.append(x)
        x.parent_class = handel_p
    elif "Kramer" in x.name:
        handel.append(x)
        x.parent_class = handel_p
    elif "Krämer" in x.name:
        handel.append(x)
        x.parent_class = handel_p

    elif "Hebam" in x.name:
        mediziner.append(x)
        x.parent_class = mediziner_p
    elif "Bader" in x.name:
        mediziner.append(x)
        x.parent_class = mediziner_p
    elif "Chiru" in x.name:
        mediziner.append(x)
        x.parent_class = mediziner_p

    elif "tudent" in x.name:
        student.append(x)
        x.parent_class = student_p

    elif "Pächter" in x.name:
        paechter.append(x)
        x.parent_class = paechter_p

    elif "Nut" in x.name:
        nutznie.append(x)
        x.parent_class = nutznie_p

    elif "Mesn" in x.name:
        mesner.append(x)
        x.parent_class = mesner_p

    elif "Inhaber" in x.name:
        inhaber.append(x)
        x.parent_class = inhaber_p

    elif "Ingehäus" in x.name:
        ingehaus.append(x)
        x.parent_class = ingehaus_p

    elif "Inwohner" in x.name:
        ingehaus.append(x)
        x.parent_class = inwohner_p

    else:
        sonstiges.append(x)
        x.parent_class = sonstiges_p
    x.save()

# %%
# create super groups for work kinds
kinds = WorkType.objects.all()

# %%
verl_super, _ = WorkType.objects.get_or_create(name='Verlassenschaftsabhandlung (Gruppe)')
rueck_super, _ = WorkType.objects.get_or_create(name='Rückstellungsinventar (Gruppe)')
stell_super, _ = WorkType.objects.get_or_create(name='Stellungsinventar (Gruppe)')
sonst_super, _ = WorkType.objects.get_or_create(name='sonstige Dokumente (Gruppe)')
archiv_super, _ = WorkType.objects.get_or_create(name='Archivbestand (Gruppe)')

# %%
verlassenschaftsabhandlung = []
rueckstellungsinventar = []
stellungsinventar = []
sonstiges = []
verfachbuch = []

for x in kinds:
    if "Verfachbuch" in x.name:
        verfachbuch.append(x)
        x.parent_class = archiv_super
    if "Verlassenschaftsabhandlung" in x.name:
        verlassenschaftsabhandlung.append(x)
        x.parent_class = verl_super
    elif "Verlasenschaftsabhandlung" in x.name:
        verlassenschaftsabhandlung.append(x)
        x.parent_class = verl_super
    elif "Verlassenschaftabhandlung" in x.name:
        verlassenschaftsabhandlung.append(x)
        x.parent_class = verl_super
    elif "Verlassentschaftsabhandlung" in x.name:
        verlassenschaftsabhandlung.append(x)
        x.parent_class = verl_super
    elif "Verlassenschaftsabhandlugn" in x.name:
        verlassenschaftsabhandlung.append(x)
        x.parent_class = verl_super
    elif "Verlassenschaftsabhandlugn" in x.name:
        verlassenschaftsabhandlung.append(x)
        x.parent_class = verl_super
    elif "Verlassenschaftsabhandlng" in x.name:
        verlassenschaftsabhandlung.append(x)
        x.parent_class = verl_super
    elif "Verlassenscahftsabhandlung" in x.name:
        verlassenschaftsabhandlung.append(x)
        x.parent_class = verl_super
    elif "Rückstellungsinventar" in x.name:
        rueckstellungsinventar.append(x)
        x.parent_class = rueck_super
    elif "Rückstellunginventar" in x.name:
        rueckstellungsinventar.append(x)
        x.parent_class = rueck_super
    elif "Stellungsin" in x.name:
        stellungsinventar.append(x)
        x.parent_class = stell_super
    else:
        sonstiges.append(x)
        x.parent_class = sonst_super
    x.save()
